# %%
# pip install pyzotero

# %%
from pyzotero import zotero
import os
import tweepy as tw
import pandas as pd
import datetime
import json, sys
from datetime import date, timedelta  
import datetime

# %% [markdown]
# # KCL intelligence

# %%
library_id = '2514686'
library_type = 'group'
api_key = '' # api_key is only needed for private groups and libraries

# %%
items = zot.everything(zot.collection_items_top('8F9EJ6CT'))

data3=[]
columns3=['Title','Publication type','Link to publication', 'Date','Abstract', 'Zotero link', 'FirstName2']

for item in items:
    data3.append((
        item['data']['title'], 
        item['data']['itemType'],
        item['data']['url'], 
        item['data'].get('date'),
        item['data']['abstractNote'], 
        item['links']['alternate']['href'],
        item['data']['creators']
        )) 
pd.set_option('display.max_colwidth', None)

df = pd.DataFrame(data3, columns=columns3)

df['Publication type'] = df['Publication type'].replace(['thesis'], 'Thesis')
df['Publication type'] = df['Publication type'].replace(['journalArticle'], 'Journal article')
df['Publication type'] = df['Publication type'].replace(['book'], 'Book')
df['Publication type'] = df['Publication type'].replace(['bookSection'], 'Book chapter')
df['Publication type'] = df['Publication type'].replace(['blogPost'], 'Blog post')
df['Publication type'] = df['Publication type'].replace(['videoRecording'], 'Video')
df['Publication type'] = df['Publication type'].replace(['podcast'], 'Podcast')
df['Publication type'] = df['Publication type'].replace(['magazineArticle'], 'Magazine article')
df['Publication type'] = df['Publication type'].replace(['webpage'], 'Webpage')
df['Publication type'] = df['Publication type'].replace(['newspaperArticle'], 'Newspaper article')
df['Publication type'] = df['Publication type'].replace(['report'], 'Report')

# df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d', errors='coerce')
# df['Date'] = df['Date'].dt.strftime('%d/%m/%Y, %H:%M')
# df['Date'] = df['Date'].dt.strftime('%d/%m/%Y')
df

# %%
df_kcl = pd.read_csv(r'C:\Users\yaozk\Downloads\Exported items.csv')
df_kcl['Publication Year'] = df_kcl['Publication Year'].fillna(0)
df_kcl['Publication Year'] = df_kcl['Publication Year'].astype(int)
df_kcl2022 = df_kcl[df_kcl['Publication Year']==2022]
df_kcl2022 = df_kcl2022.reset_index(drop=True)
df_kcl2022.rename(columns={'Item Type':'Publication type'}, inplace=True)

df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['thesis'], 'Thesis')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['journalArticle'], 'Journal article')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['book'], 'Book')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['bookSection'], 'Book chapter')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['blogPost'], 'Blog post')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['videoRecording'], 'Video')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['podcast'], 'Podcast')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['magazineArticle'], 'Magazine article')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['webpage'], 'Webpage')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['newspaperArticle'], 'Newspaper article')
df_kcl2022['Publication type'] = df_kcl2022['Publication type'].replace(['report'], 'Report')

df_kcl2022
# Out:
#          Key   Publication type  Publication Year  \
# 0   4CBNHWV6               Book              2022
# 1   RRG5UX8I    Journal article              2022
# 2   KYRIW5WE          Blog post              2022
# 3   PKWQJG8F               Book              2022
# 4   NIVNR8MI  Newspaper article              2022
# 5   Q2XLRGSB          Blog post              2022
# 6   F44K6JA9          Blog post              2022
# 7   Q859QLI7    Journal article              2022
# 8   HPE8QB5E    Journal article              2022
# 9   MF43NZR6              Video              2022
# 10  CTSI84EI  Newspaper article              2022
# 11  ZWRFYLAW    Journal article              2022
# 12  8GURKV4L               Book              2022
# 13  ISGJHVNN       Book chapter              2022
# 14  YEYRSDJ4       Book chapter              2022
# 15  P6QQPP8R          Blog post              2022
# 16  SEPWVIM2            Podcast              2022
# 17  FHQEEXDH               Book              2022
# 18  EPLCQTS5          Blog post              2022
# 19  RZA8Q8NJ    Journal article              2022
# 20  X4CSZ8YF    Journal article              2022
# 21  LMNWXQSE          Blog post              2022
# 22  4JZ8BS7L    conferencePaper              2022
# 23  BBSGUMGR    Journal article              2022
# 24  4CRWVXDW          Blog post              2022
# 25  LLKV8M7I          Blog post              2022
# 26  RHXT5FL7    Journal article              2022
#
#                                                                Author  \
# 0                                                                 NaN
# 1                                                 Richterova, Daniela
# 2                                                      Raine, Suzanne
# 3                                    Herman, Michael; Schaefer, David
# 4                                          Gioe, David V.; Dylan, Huw
# 5                                                    Elena, Grossfeld
# 6                            Dylan, Huw; Gioe, David V.; Littell, Joe
# 7                                     Gioe, David V.; Styles, William
# 8                                      Dylan, Huw; Maguire, Thomas J.
# 9                             The Joint Special Operations University
# 10                                                          King, Jon
# 11                                                   Ozkan, Yusuf Ali
# 12                                                                NaN
# 13                                             Buck, Gary; Dylan, Huw
# 14                                                  Burnett, Berenice
# 15                                                     Gioe, David V.
# 16             Gioe, David V.; Stolworthy, Kenneth; Lester, Genevieve
# 17                                                                NaN
# 18                                        Dylan, Huw; Maguire, Thomas
# 19                                                        Long, Magda
# 20               Yelamos, Charlotte; Goodman, Michael S.; Stout, Mark
# 21                                      Buchan, Russell; Devanny, Joe
# 22                                                       Stevens, Tim
# 23                       Devanny, Joe; Goldoni, Luiz; Medeiros, Breno
# 24                                                    Devanny, Joseph
# 25                                                         Dylan, Huw
# 26  Devanny, Joe; Goldoni, Luiz Rogério Franco; Medeiros, Breno Pauli
#
#                                                                                                                          Title  \
# 0                                                                                                 Health Security Intelligence
# 1                                                         Reconnecting the dots: state-terrorist relations during the Cold War
# 2                                                                               A Provocative Challenge to Analytical Doctrine
# 3                                                                                               Intelligence Power in Practice
# 4                                                                Putin’s KGB past didn’t help him with intelligence on Ukraine
# 5                                                             What does the War in Ukraine tell us about Russian Intelligence?
# 6                                                                  The Kherson Ruse: Ukraine and the Art of Military Deception
# 7                                                                            Vladimir Putin’s Russian World Turned Upside Down
# 8                                                                  Secret Intelligence and Public Diplomacy in the Ukraine War
# 9                                                                                              The British Way in Intelligence
# 10                                                          Putin's Ukraine war 'a major intelligence failure' for the Kremlin
# 11                                                    British intelligence and the Dardanelles: the 1906 Taba affair revisited
# 12                                                                   A Research Agenda for Intelligence Studies and Government
# 13                                                                                 Deception and Intelligence in Peace and War
# 14                                                                                               Post-Modern Archival Research
# 15                                                          Democratised and declassified: the era of social media war is here
# 16                                                                          Every citizen a sensor? Democratizing intelligence
# 17                          Estimative Intelligence in European Foreign Policymaking: Learning Lessons from an Era of Surprise
# 18                         Why are governments sharing intelligence on the Ukraine war with the public and what are the risks?
# 19                                                                             American Covert Action and Diplomacy after 9/11
# 20                                                                                   Intelligence and culture: an introduction
# 21  Clarifying Responsible Cyber Power: Developing Views in the U.K. Regarding Non-intervention and Peacetime Cyber Operations
# 22                                                      Cyber Risk: Hyperconnectivity and the Political Economy of Uncertainty
# 23                                                          Strategy in an Uncertain Domain: Threat and Response in Cyberspace
# 24                                                            Cyberspace and the conflict in Ukraine: a provisional assessment
# 25            How has public intelligence transformed the way this war has been reported? | Feature from King's College London
# 26                                                                                           The rise of cyber power in Brazil
#
#                                             Publication Title  \
# 0                                                         NaN
# 1                          Intelligence and National Security
# 2                                                        RUSI
# 3                                                         NaN
# 4                                             Washington Post
# 5                                       King's College London
# 6                                        Modern War Institute
# 7                                      Armed Forces & Society
# 8                                                    Survival
# 9                                                         NaN
# 10                                              Express.co.uk
# 11                         Intelligence and National Security
# 12                                                        NaN
# 13  A Research Agenda for Intelligence Studies and Government
# 14  A Research Agenda for Intelligence Studies and Government
# 15                                           Engelsberg ideas
# 16                                                        NaN
# 17                                                        NaN
# 18                                           The Conversation
# 19                                     Diplomacy & Statecraft
# 20                         Intelligence and National Security
# 21                                                    Lawfare
# 22                                                        NaN
# 23                              Journal of Strategic Security
# 24                                    UK in a changing Europe
# 25                                                        NaN
# 26               Revista Brasileira de Política Internacional
#
#                  ISBN                                            ISSN  \
# 0                 NaN                                             NaN
# 1                 NaN                                       0268-4527
# 2                 NaN                                             NaN
# 3                 NaN                                             NaN
# 4                 NaN                                       0190-8286
# 5                 NaN                                             NaN
# 6                 NaN                                             NaN
# 7                 NaN                                       0095-327X
# 8                 NaN                                       0039-6338
# 9                 NaN                                             NaN
# 10                NaN                                             NaN
# 11                NaN                                       0268-4527
# 12  978-1-80037-880-3                                             NaN
# 13  978-1-80037-880-3                                             NaN
# 14  978-1-80037-880-3                                             NaN
# 15                NaN                                             NaN
# 16                NaN                                             NaN
# 17                NaN                                             NaN
# 18                NaN                                             NaN
# 19                NaN                                       0959-2296
# 20                NaN                                       0268-4527
# 21                NaN                                             NaN
# 22                NaN                                             NaN
# 23                NaN  1944-0464 (Print)</br>ISSN: 1944-0472 (Online)
# 24                NaN                                             NaN
# 25                NaN                                             NaN
# 26                NaN                            0034-7329, 1983-3121
#
#                                             DOI  \
# 0                                           NaN
# 1                 10.1080/02684527.2021.2001956
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                     10.1177/0095327X221121778
# 8                 10.1080/00396338.2022.2103257
# 9                                           NaN
# 10                                          NaN
# 11                10.1080/02684527.2022.2055936
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                10.1080/09592296.2022.2062133
# 20                10.1080/02684527.2022.2065610
# 21                                          NaN
# 22                                          NaN
# 23  https://doi.org/10.5038/1944-0472.15.2.1954
# 24                                          NaN
# 25                                          NaN
# 26                   10.1590/0034-7329202200113
#
#                                                                                                                                                                   Url  \
# 0                                                                  https://www.routledge.com/Health-Security-Intelligence/Goodman-Wilson-Lentzos/p/book/9781032157382
# 1                                                                                                                       https://doi.org/10.1080/02684527.2021.2001956
# 2                                                             https://rusi.org/explore-our-research/publications/commentary/provocative-challenge-analytical-doctrine
# 3                                                                                       https://edinburghuniversitypress.com/book-intelligence-power-in-practice.html
# 4                                                         https://www.washingtonpost.com/outlook/2022/03/17/putins-kgb-past-didnt-help-him-with-intelligence-ukraine/
# 5                                                                               https://www.kcl.ac.uk/what-does-the-war-in-ukraine-tell-us-about-russian-intelligence
# 6                                                                                    https://mwi.usma.edu/the-kherson-ruse-ukraine-and-the-art-of-military-deception/
# 7                                                                                                                           https://doi.org/10.1177/0095327X221121778
# 8                                                                                                                       https://doi.org/10.1080/00396338.2022.2103257
# 9                                                                                                    https://www.youtube.com/watch?v=rnqY4zvyKLA&ab_channel=ThinkJSOU
# 10                                                https://www.express.co.uk/news/world/1582628/ukraine-war-vladimir-putin-russia-michael-goodman-kings-college-london
# 11                                                                                                                      https://doi.org/10.1080/02684527.2022.2055936
# 12                                                                                              https://www.elgaronline.com/view/book/9781800378803/9781800378803.xml
# 13                                                                                 https://www.elgaronline.com/view/book/9781800378803/book-part-9781800378803-19.xml
# 14                                                                                 https://www.elgaronline.com/view/book/9781800378803/book-part-9781800378803-22.xml
# 15                                                            https://engelsbergideas.com/notebook/democratised-and-declassified-the-era-of-social-media-war-is-here/
# 16                                                                                                   https://warroom.armywarcollege.edu/podcasts/democratizing-intel/
# 17                                                            https://edinburghuniversitypress.com/book-estimative-intelligence-in-european-foreign-policymaking.html
# 18                               http://theconversation.com/why-are-governments-sharing-intelligence-on-the-ukraine-war-with-the-public-and-what-are-the-risks-191114
# 19                                                                                                                      https://doi.org/10.1080/09592296.2022.2062133
# 20                                                                                                                      https://doi.org/10.1080/02684527.2022.2065610
# 21                                        https://www.lawfareblog.com/clarifying-responsible-cyber-power-developing-views-uk-regarding-non-intervention-and-peacetime
# 22  https://kclpure.kcl.ac.uk/portal/en/publications/cyber-risk-hyperconnectivity-and-the-political-economy-of-uncertainty(2777a97d-7212-442d-a992-bfbf8e096acc).html
# 23                                                                                                                    https://digitalcommons.usf.edu/jss/vol15/iss2/3
# 24                                                                                                              https://ukandeu.ac.uk/cyberspace-conflict-in-ukraine/
# 25                                                                   https://www.kcl.ac.uk/how-has-public-intelligence-transformed-the-way-this-war-has-been-reported
# 26                                                                                                     http://www.scielo.br/j/rbpi/a/gCyg54zVhCVm35jm6n7VPnw/?lang=en
#
#     ... Programming Language Version System Code Code Number Section Session  \
# 0   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 1   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 2   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 3   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 4   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 5   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 6   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 7   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 8   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 9   ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 10  ...                  NaN     NaN    NaN  NaN         NaN   World     NaN
# 11  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 12  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 13  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 14  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 15  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 16  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 17  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 18  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 19  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 20  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 21  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 22  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 23  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 24  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 25  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
# 26  ...                  NaN     NaN    NaN  NaN         NaN     NaN     NaN
#
#     Committee  History  Legislative Body
# 0         NaN      NaN               NaN
# 1         NaN      NaN               NaN
# 2         NaN      NaN               NaN
# 3         NaN      NaN               NaN
# 4         NaN      NaN               NaN
# 5         NaN      NaN               NaN
# 6         NaN      NaN               NaN
# 7         NaN      NaN               NaN
# 8         NaN      NaN               NaN
# 9         NaN      NaN               NaN
# 10        NaN      NaN               NaN
# 11        NaN      NaN               NaN
# 12        NaN      NaN               NaN
# 13        NaN      NaN               NaN
# 14        NaN      NaN               NaN
# 15        NaN      NaN               NaN
# 16        NaN      NaN               NaN
# 17        NaN      NaN               NaN
# 18        NaN      NaN               NaN
# 19        NaN      NaN               NaN
# 20        NaN      NaN               NaN
# 21        NaN      NaN               NaN
# 22        NaN      NaN               NaN
# 23        NaN      NaN               NaN
# 24        NaN      NaN               NaN
# 25        NaN      NaN               NaN
# 26        NaN      NaN               NaN
#
# [27 rows x 87 columns]

# %%
n = 10

for i in range(1, n+1):
    if (n%i==0):
        print(i, end=" ")
# Out:
# 1 2 5 10

# %%
zot = zotero.Zotero(library_id, library_type)

# %%
collection_code = 'TDUVX2TF'

count_collection = zot.num_collectionitems(collection_code)

items = zot.everything(zot.collection_items_top(collection_code))

data3=[]
columns3=['Title','Publication type', 'Link to publication', 'Abstract', 'Zotero link', 'FirstName2']

for item in items:
    data3.append((
        item['data']['title'], 
        item['data']['itemType'], 
        item['data']['url'], 
        item['data']['abstractNote'], 
        item['links']['alternate']['href'],
        item['data']['creators']
        )) 
pd.set_option('display.max_colwidth', None)

df = pd.DataFrame(data3, columns=columns3)

value = df['FirstName2'].isnull()

# %%
if item['data']['creators'] in ("", [], None, 0, False):
    print('y')
else:
    print('m')
# Out:
# m

# %%
pd.set_option('display.max_colwidth', None)

data=[]
columns = ['Title','Publication type', 'Link to publication', 'Abstract', 'Zotero link', 'Date added']

for item in items:
    data.append((item['data']['title'], item['data']['itemType'], item['data']['url'], item['data']['abstractNote'], item['links']['alternate']['href'], item['data']['dateAdded'],))

df = pd.DataFrame(data, columns=columns)
df.head(1)
# Out:
#                                     Title Publication type  \
# 0  King's Intelligence and Security Group          webpage
#
#    Link to publication                                Abstract  \
# 0  https://kisg.co.uk/  King's Intelligence and Security Group
#
#                                                               Zotero link  \
# 0  https://www.zotero.org/groups/intelligence_bibliography/items/924CQCZR
#
#              Date added
# 0  2022-12-08T20:24:12Z

# %%
zot = zotero.Zotero(library_id, library_type)
items = zot.collection_items_top('BNPYHVD4', limit=10)
pd.set_option('display.max_colwidth', None)

# %%
pd.set_option('display.max_colwidth', None)

data=[]
columns = ['Title','Publication type', 'Link to publication','Publication date', 'Date added', 'Collection']

for item in items:
    data.append((item['data']['title'], item['data']['itemType'], item['data']['url'], item['data']['date'], item['data']['dateAdded'], item['data']['collections'])) 

df = pd.DataFrame(data, columns=columns)
# df=df_q.style.set_properties(**{'text-align': 'left'})
df['Date added'] = pd.to_datetime(df['Date added'], errors='coerce')
df['Date added'] = df['Date added'].dt.strftime('%d/%m/%Y')

df['Publication date'] = pd.to_datetime(df['Publication date'], errors='coerce')
df['Publication date'] = df['Publication date'].dt.strftime('%d/%m/%Y')
df['Publication type'] = df['Publication type'].replace(['thesis'], 'Thesis')
df['Publication type'] = df['Publication type'].replace(['journalArticle'], 'Journal article')
df['Publication type'] = df['Publication type'].replace(['book'], 'Book')
df['Publication type'] = df['Publication type'].replace(['bookSection'], 'Book chapter')
df['Publication type'] = df['Publication type'].replace(['blogPost'], 'Blog post')

# %%
df_last = '**'+ df['Publication type']+ '**'+ ': ' + '['+ df['Title']+']' +'('+ df['Link to publication'] + ')' + ' (Published on: ' +df['Publication date'].astype(str) + ')'

# %%
aaa = zot.collections()

data2=[]
columns2 = ['Code','Name', 'Number', 'Link', 'Parent collection code']
for item in aaa:
    data2.append((item['data']['key'], item['data']['name'], item['meta']['numItems'], item['links']['alternate']['href'], item['data']['parentCollection']))

pd.set_option('display.max_colwidth', None)
df_collections = pd.DataFrame(data2, columns=columns2)

# %%
# df.to_csv('dataset.csv', encoding="utf-8-sig")

# %%
import numpy as np
import pandas as pd

# %%
json_list = [
    { 
        'class': 'Year 1', 
        'student count': 20, 
        'room': 'Yellow',
        'info': {
            'teachers': { 
                'math': 'Rick Scott', 
                'physics': 'Elon Mask' 
            }
        },
        'students': [
            { 
                'name': 'Tom', 
                'sex': 'M', 
                'grades': { 'math': 66, 'physics': 77 } 
            },
            { 
                'name': 'James', 
                'sex': 'M', 
                'grades': { 'math': 80, 'physics': 78 } 
            },
        ]
    },
    { 
        'class': 'Year 2', 
        'student count': 25, 
        'room': 'Blue',
        'info': {
            'teachers': { 
                'math': 'Alan Turing', 
                'physics': 'Albert Einstein' 
            }
        },
        'students': [
            { 'name': 'Tony', 'sex': 'M' },
            { 'name': 'Jacqueline', 'sex': 'F' },
        ]
    },
]

# %%
pd.json_normalize(json_list)
# Out:
#     class  student count    room  \
# 0  Year 1             20  Yellow
# 1  Year 2             25    Blue
#
#                                             students info.teachers.math  \
# 0  [{'name': 'Tom', 'sex': 'M', 'grades': {'math'...         Rick Scott
# 1  [{'name': 'Tony', 'sex': 'M'}, {'name': 'Jacqu...        Alan Turing
#
#   info.teachers.physics
# 0             Elon Mask
# 1       Albert Einstein

# %%
pd.json_normalize(json_list, record_path=['students'])
# Out:
#          name sex  grades.math  grades.physics
# 0         Tom   M         66.0            77.0
# 1       James   M         80.0            78.0
# 2        Tony   M          NaN             NaN
# 3  Jacqueline   F          NaN             NaN

# %%
data = [
{"creatorType":"author","firstName":"Mark","lastName":"Mazzetti"},
{"creatorType":"author","firstName":"Joshua","lastName":"Rovner"}
]

# %%
data
# Out:
# [{'creatorType': 'author', 'firstName': 'Mark', 'lastName': 'Mazzetti'},
#  {'creatorType': 'author', 'firstName': 'Joshua', 'lastName': 'Rovner'}]

# %%
pd.json_normalize(
    data
    
    )
# Out:
#   creatorType firstName  lastName
# 0      author      Mark  Mazzetti
# 1      author    Joshua    Rovner

# %%
zot = zotero.Zotero(library_id, library_type)
items = zot.top(limit=10)

data=[]
columns = ['Title','Publication type', 'Link to publication', 'Abstract', 'Zotero link', 'Date added', 'Col key', 'FirstName']

for item in items:
    data.append((item['data']['title'], 
    item['data']['itemType'], 
    item['data']['url'], 
    item['data']['abstractNote'], 
    item['links']['alternate']['href'], 
    item['data']['dateAdded'], 
    item['data']['collections'],
    item['data']['creators']
    ))

pd.set_option('display.max_colwidth', None)
df = pd.DataFrame(data, columns=columns)


df_new = pd.json_normalize(df['FirstName'])
df_new = df_new[0]
df_new = pd.json_normalize(df_new)
df_new
# Out:
#   creatorType                         firstName   lastName
# 0      author  King's Intelligence and Security      Group
# 1      author                              Mark   Mazzetti
# 2      author                           Rebecca  Nicholson
# 3      author                             Helen    Warrell
# 4      author                         Elisabeth       Braw
# 5      author                        Richard J.    Aldrich
# 6      author                         Elisabeth       Braw
# 7      author                            Joshua     Rovner
# 8      author                             James   Lockhart
# 9      author                      Daniel W. B.      Lomas

# %%
nums = {'Integers_1': [10, 15, 30, 40, 55, np.nan, 75,
                       np.nan, 90, 150, np.nan],
        'Integers_2': [np.nan, 21, 22, 23, np.nan, 24, 25,
                       np.nan, 26, np.nan, np.nan]}

# %%
df = pd.DataFrame(nums, columns=['Integers_1', 'Integers_2'])
df
# Out:
#     Integers_1  Integers_2
# 0         10.0         NaN
# 1         15.0        21.0
# 2         30.0        22.0
# 3         40.0        23.0
# 4         55.0         NaN
# 5          NaN        24.0
# 6         75.0        25.0
# 7          NaN         NaN
# 8         90.0        26.0
# 9        150.0         NaN
# 10         NaN         NaN

# %%
collection_code = 'N7Y6M96D'
count_collection = zot.num_collectionitems(collection_code)

items = zot.everything(zot.collection_items_top(collection_code))

data3=[]
columns3=['Title','Publication type', 'Link to publication', 'Abstract', 'Zotero link', 'FirstName2']

for item in items:
    data3.append((
        item['data']['title'], 
        item['data']['itemType'], 
        item['data']['url'], 
        item['data']['abstractNote'], 
        item['links']['alternate']['href'],
        item['data']['creators']
        )) 
pd.set_option('display.max_colwidth', None)

df = pd.DataFrame(data3, columns=columns3)
df['FirstName2']= [x if len(x) else {"creatorType":"author","firstName":"null","lastName":"null"} for x in df['FirstName2']]
df
# Out:
#                                                                                              Title  \
# 0                                List of preprint servers: policies and practices across platforms
# 1                                                                                        Preprints
# 2                                                                   Preprints - About - Europe PMC
# 3                                                               Open Access Policy - Grant Funding
# 4  Peer Community In – A free recommendation process of scientific preprints based on peer-reviews
#
#   Publication type  \
# 0          webpage
# 1          webpage
# 2          webpage
# 3          webpage
# 4          webpage
#
#                                                                                                     Link to publication  \
# 0                                                                                  https://asapbio.org/preprint-servers
# 1  http://www.imperial.ac.uk/research-and-innovation/support-for-staff/scholarly-communication/open-research/preprints/
# 2                                                                                       https://europepmc.org/Preprints
# 3                                   https://wellcome.org/grant-funding/guidance/open-access-guidance/open-access-policy
# 4                                                                                          https://peercommunityin.org/
#
#                                                                                                                                                                                                                                                                                                                                                                                              Abstract  \
# 0  Given the growth of preprint servers and alternative platforms, it is increasingly important to describe their disciplinary scope and compare and contrast policies including governance, licensing, archiving strategies and the nature of any screening checks. These practices are important to both researchers and policymakers. Here we present a list of preprint servers relevant to life…
# 1                                                                                                                                                                                                                                             A preprint is a full draft of a research paper that is shared publicly before it has been peer reviewed by a journal. There are many different names...
# 2
# 3                                                                                                                                                                                                                                                 Find out about Wellcome's open access grant funding policy which says there must be unrestricted access to the published output of funded research.
# 4
#
#                                                            Zotero link  \
# 0  https://www.zotero.org/groups/open_access_literature/items/HTHH3KAX
# 1  https://www.zotero.org/groups/open_access_literature/items/827NVYCW
# 2  https://www.zotero.org/groups/open_access_literature/items/TTSIP9CZ
# 3  https://www.zotero.org/groups/open_access_literature/items/YFRGDUQI
# 4  https://www.zotero.org/groups/open_access_literature/items/YTV3DW75
#
#                                                            FirstName2
# 0  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
# 1  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
# 2  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
# 3  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
# 4  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}

# %%
df_fa = pd.DataFrame(df_fa.tolist())
df_fa
# df_fa = df_fa[0]
df_fa = df_fa.apply(lambda x: {} if pd.isna(x) else x) # https://stackoverflow.com/questions/44050853/pandas-json-normalize-and-null-values-in-json
df_new = pd.json_normalize(df_fa, errors='ignore') 
df = pd.concat([df, df_new], axis=1)
df['firstName'] = df['firstName'].fillna('null')
df['lastName'] = df['lastName'].fillna('null')

# %%
sample = [{'_id': '5f48bee4c54cf6b5e8048274',
          'created_at': '2020-08-28T08:23:00Z',
          'sections': [{'comment': '',
            'type_fail': None,
            'answers': [{'comment': 'stuff',
              'feedback': [],
              'value': 10.0,
              'answer_type': 'default',
              'question_id': '5e59599c68369c24069630fd',
              'answer_id': '5e595a7c3fbb70448b6ff935'},
             {'comment': 'stuff',
              'feedback': [],
              'value': 10.0,
              'answer_type': 'default',
              'question_id': '5e598939cedcaf5b865ef99a',
              'answer_id': '5e598939cedcaf5b865ef998'}],
            'score': 20.0,
            'passed': True,
            '_id': '5e59599c68369c24069630fe',
            'custom_fields': []},
           {'comment': '',
            'type_fail': None,
            'answers': [{'comment': '',
              'feedback': [],
              'value': None,
              'answer_type': 'not_applicable',
              'question_id': '5e59894f68369c2398eb68a8',
              'answer_id': '5eaad4e5b513aed9a3c996a5'},
             {'comment': '',
              'feedback': [],
              'value': None,
              'answer_type': 'not_applicable',
              'question_id': '5e598967cedcaf5b865efe3e',
              'answer_id': '5eaad4ece3f1e0794372f8b2'},
             {'comment': "stuff",
              'feedback': [],
              'value': 0.0,
              'answer_type': 'default',
              'question_id': '5e598976cedcaf5b865effd1',
              'answer_id': '5e598976cedcaf5b865effd3'}],
            'score': 0.0,
            'passed': True,
            '_id': '5e59894f68369c2398eb68a9',
            'custom_fields': []}]},
         {'_id': '5f48f708fe22ca4d15fb3b55',
          'created_at': '2020-08-28T12:22:32Z',
          'sections': []}]

# %%
count_collection = zot.num_collectionitems(collection_code)

items = zot.everything(zot.collection_items_top(collection_code))

data3=[]
columns3=['Title','Publication type', 'Link to publication', 'Abstract', 'Zotero link', 'FirstName2']

for item in items:
    data3.append((
        item['data']['title'], 
        item['data']['itemType'], 
        item['data']['url'], 
        item['data']['abstractNote'], 
        item['links']['alternate']['href'],
        item['data']['creators']
        )) 
pd.set_option('display.max_colwidth', None)

df = pd.DataFrame(data3, columns=columns3)

df['FirstName2']= [x if len(x) else {"creatorType":"author","firstName":"null","lastName":"null"} for x in df['FirstName2']]
df
df_fa = df['FirstName2']
df_fa = pd.DataFrame(df_fa.tolist())
df = pd.concat([df, df_fa], axis=1)
# Out:
#                                                                                              Title  \
# 0                                List of preprint servers: policies and practices across platforms
# 1                                                                                        Preprints
# 2                                                                   Preprints - About - Europe PMC
# 3                                                               Open Access Policy - Grant Funding
# 4  Peer Community In – A free recommendation process of scientific preprints based on peer-reviews
#
#   Publication type  \
# 0          webpage
# 1          webpage
# 2          webpage
# 3          webpage
# 4          webpage
#
#                                                                                                     Link to publication  \
# 0                                                                                  https://asapbio.org/preprint-servers
# 1  http://www.imperial.ac.uk/research-and-innovation/support-for-staff/scholarly-communication/open-research/preprints/
# 2                                                                                       https://europepmc.org/Preprints
# 3                                   https://wellcome.org/grant-funding/guidance/open-access-guidance/open-access-policy
# 4                                                                                          https://peercommunityin.org/
#
#                                                                                                                                                                                                                                                                                                                                                                                              Abstract  \
# 0  Given the growth of preprint servers and alternative platforms, it is increasingly important to describe their disciplinary scope and compare and contrast policies including governance, licensing, archiving strategies and the nature of any screening checks. These practices are important to both researchers and policymakers. Here we present a list of preprint servers relevant to life…
# 1                                                                                                                                                                                                                                             A preprint is a full draft of a research paper that is shared publicly before it has been peer reviewed by a journal. There are many different names...
# 2
# 3                                                                                                                                                                                                                                                 Find out about Wellcome's open access grant funding policy which says there must be unrestricted access to the published output of funded research.
# 4
#
#                                                            Zotero link  \
# 0  https://www.zotero.org/groups/open_access_literature/items/HTHH3KAX
# 1  https://www.zotero.org/groups/open_access_literature/items/827NVYCW
# 2  https://www.zotero.org/groups/open_access_literature/items/TTSIP9CZ
# 3  https://www.zotero.org/groups/open_access_literature/items/YFRGDUQI
# 4  https://www.zotero.org/groups/open_access_literature/items/YTV3DW75
#
#                                                            FirstName2  \
# 0  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
# 1  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
# 2  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
# 3  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
# 4  {'creatorType': 'author', 'firstName': 'null', 'lastName': 'null'}
#
#   creatorType firstName lastName
# 0      author      null     null
# 1      author      null     null
# 2      author      null     null
# 3      author      null     null
# 4      author      null     null
